# %% [markdown]
# ## How to handle null values

# %% [markdown]
# 1. Deleting Rows
# 2. Replacing With Mean/Median/Mode
# 3. Predicting The Missing Values
# 4. Using Algorithms Which Support Missing Values

# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer

# %%
series = pd.read_csv(r'https://raw.githubusercontent.com/armangh67/LSTM/main/Turbine_Data.csv')

# %%
df_selected = series[['Unnamed: 0','ActivePower','AmbientTemperatue','WindDirection','WindSpeed','BearingShaftTemperature','RotorRPM']]
df = df_selected.rename(columns = {'Unnamed: 0':'Date'})     ####### rename the date column ######
df['Date'] = pd.to_datetime(df['Date'])
dataset = df.set_index('Date')
dataset = dataset.loc['2020-01-01':]
dataset.head(10)
# Out:
#                            ActivePower  AmbientTemperatue  WindDirection  \
# Date
# 2020-01-01 00:00:00+00:00   360.361251          22.485462          191.0
# 2020-01-01 00:10:00+00:00   550.814483          22.636076          198.5
# 2020-01-01 00:20:00+00:00   658.713983          22.612143            NaN
# 2020-01-01 00:30:00+00:00   958.625087          22.565534          195.2
# 2020-01-01 00:40:00+00:00   743.454246          22.489755            NaN
# 2020-01-01 00:50:00+00:00   556.442579          22.424343          188.0
# 2020-01-01 01:00:00+00:00   496.701493          22.347917          194.0
# 2020-01-01 01:10:00+00:00   525.987062          22.517698          194.0
# 2020-01-01 01:20:00+00:00   371.789686          22.420327          194.0
# 2020-01-01 01:30:00+00:00   381.242069          22.464487          195.8
#
#                            WindSpeed  BearingShaftTemperature   RotorRPM
# Date
# 2020-01-01 00:00:00+00:00   5.547000                41.554237   9.516714
# 2020-01-01 00:10:00+00:00   6.375833                41.517490  10.967926
# 2020-01-01 00:20:00+00:00   7.099773                41.731771  11.557699
# 2020-01-01 00:30:00+00:00   7.366228                42.267183  13.010639
# 2020-01-01 00:40:00+00:00   6.956225                42.565918  11.956652
# 2020-01-01 00:50:00+00:00   6.476373                42.219699  10.957252
# 2020-01-01 01:00:00+00:00   6.158284                41.793870  10.504177
# 2020-01-01 01:10:00+00:00   6.265139                41.650928  10.683153
# 2020-01-01 01:20:00+00:00   5.659305                41.423102   9.569801
# 2020-01-01 01:30:00+00:00   5.895858                41.220459   9.705768

# %%
dataset.isnull().sum()
# Out:
# ActivePower                178
# AmbientTemperatue          832
# WindDirection              730
# WindSpeed                  178
# BearingShaftTemperature    835
# RotorRPM                   842
# dtype: int64

# %%
def fill_null(data,neighbors):
    knn = KNNImputer(n_neighbors = neighbors, add_indicator = True)
    knn.fit(data)
    df = pd.DataFrame(knn.transform(data))
    a = list(data)
    x = []
    for i in range(data.shape[1]):
        x.append(np.array(df.iloc[:,i]))
    for i in range(data.shape[1]):
        data[(a[i])] = x[i] 
    return data

# %%
df1 = fill_null(dataset,500)
df1.head(10)
# Out:
#                            ActivePower  AmbientTemperatue  WindDirection  \
# Date
# 2020-01-01 00:00:00+00:00   360.361251          22.485462     191.000000
# 2020-01-01 00:10:00+00:00   550.814483          22.636076     198.500000
# 2020-01-01 00:20:00+00:00   658.713983          22.612143     175.930932
# 2020-01-01 00:30:00+00:00   958.625087          22.565534     195.200000
# 2020-01-01 00:40:00+00:00   743.454246          22.489755     175.338572
# 2020-01-01 00:50:00+00:00   556.442579          22.424343     188.000000
# 2020-01-01 01:00:00+00:00   496.701493          22.347917     194.000000
# 2020-01-01 01:10:00+00:00   525.987062          22.517698     194.000000
# 2020-01-01 01:20:00+00:00   371.789686          22.420327     194.000000
# 2020-01-01 01:30:00+00:00   381.242069          22.464487     195.800000
#
#                            WindSpeed  BearingShaftTemperature   RotorRPM
# Date
# 2020-01-01 00:00:00+00:00   5.547000                41.554237   9.516714
# 2020-01-01 00:10:00+00:00   6.375833                41.517490  10.967926
# 2020-01-01 00:20:00+00:00   7.099773                41.731771  11.557699
# 2020-01-01 00:30:00+00:00   7.366228                42.267183  13.010639
# 2020-01-01 00:40:00+00:00   6.956225                42.565918  11.956652
# 2020-01-01 00:50:00+00:00   6.476373                42.219699  10.957252
# 2020-01-01 01:00:00+00:00   6.158284                41.793870  10.504177
# 2020-01-01 01:10:00+00:00   6.265139                41.650928  10.683153
# 2020-01-01 01:20:00+00:00   5.659305                41.423102   9.569801
# 2020-01-01 01:30:00+00:00   5.895858                41.220459   9.705768

# %%
df1.isna().sum()
# Out:
# ActivePower                0
# AmbientTemperatue          0
# WindDirection              0
# WindSpeed                  0
# BearingShaftTemperature    0
# RotorRPM                   0
# dtype: int64
